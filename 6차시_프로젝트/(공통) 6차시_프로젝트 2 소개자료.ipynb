# %% [markdown]
# # [6차시] 프로젝트 2 : 캐글러가 되자 - Housing data (1)
# ***본 자료는 원활한 프로젝트 수행을 위한 소개자료입니다. 코드리뷰를 위한 파일 제출은 제공된 압축파일 내 '6차시_프로젝트 2 제출코드.ipynb'를 활용해주세요.***

# %% [markdown]
# ### 캐글을 소개합니다.
#
# 머신러닝 혹은 데이터와 관련된 커리어를 만들기 위해서 필요한 경험 중 하나는 프로젝트 수행 경험입니다. 회사에서는 단순히 지식을 많이 가지고 있는 사람을 뽑는 것이 아니라 어느 정도 실무경험을 갖추고 있으며 협업이 가능한 사람을 뽑고 싶어 합니다. 성공적인 프로젝트 경험을 가지고 있는 구직자 분들은 자신을 증명할 수 있는 좋은 도구를 갖췄다고 보셔도 됩니다. 그러나 초보자가 프로젝트 경험을 쌓기는 쉽지 않습니다. 일반적으로 프로젝트 팀원은 실력있고 경험있는 사람들로 구성되죠.
#
# 초보자가 머신러닝 관련 프로젝트를 시작하는 좋은 방법 중 하나는 데이터분석 관련 대회에 참여해 보는것 입니다. 대회는 데이터를 제공하며, 프로젝트에서 수행해야 할 목표가 명확하게 제시되어 있고, 일반적으로 누구나 참여할 수 있게 열려 있습니다.
#
# 본 미션에서는 여러분과 함께 [캐글 (Kaggle)](https://www.kaggle.com/)이라는 데이터 분석 대회 플랫폼에 가입하고, 실제 데이터를 분석해 보도록 하려고 합니다. 본 미션들을 통해서 여러분은 다음과 같은 내용을 학습하게 됩니다.
#
# * 캐글에 가입하고 참여해보는 과정을 경험한다.
# * 데이터를 분석하기 위해 필요한 전처리 기술을 학습한다.
# * 지금까지 배운 내용을 새로운 데이터에 적용해본다.

# %% [markdown]
# ### 캐글 가입하기 : 계정 프로필명 공유
#
# [캐글](https://www.kaggle.com/)(Kaggle)은 앞서 언급했듯이 데이터 과학자들이 다양한 문제를 해결하고 커뮤니티를 형성하여 지식을 공유하는 데이터분석 대회 플랫폼 입니다.
#
# 가입을 안하신 분들은 다음과 같이 가입을 진행해 주세요. 구글 아이디를 활용하여 쉽게 가입할 수 있으니 빠르게 진행해 보죠.
# 1. 링크를 눌러서 캐글에 접속합니다 : https://www.kaggle.com/
# 2. 이미 가입이 되어있다면 오른쪽 상단의 `Sign In` 버튼을 눌러서 로그인을 완료해주세요.
# 3. 가입이 안되어 있다면 `Register`버튼을 눌러서 가입 및 로그인을 완료해주세요.
#
# ![캐글 가입.png](data:image/png;base64,...)

# %% [markdown]
# ### 캐글 대회 참여하기 : Housing Price Prediction
#
# 캐글에는 아주 다양한 경진대회들이 있고, 각 경진대회들은 모두 대회 소개, 데이터셋 소개, 규칙 설명 등 대회에 참가하는 사람들을 위한 세부 내용들로 구성되어 있습니다.
#
# 우리가 이번에 참여할 대회의 이름과 링크는 아래와 같습니다. 아래의 링크를 눌러서 확인해주세요.
#
# * [캐글 코리아와 함께하는 2nd ML 대회 - House Price Prediction](https://www.kaggle.com/c/2019-2nd-ml-month-with-kakr)
#
# 이 대회는 특이하게도 무분별한 외국인들의 참가를 방지하기 위해 참여링크가 따로 존재합니다. 다시 링크를 눌러 리디렉션된 상태에서 참여가 가능하다고 하네요. 또한 Overview 페이지에서 대회의 Description, Evaluation, Prize, Timeline을 확인하실 수 있습니다.
#
# ![캐글 대회개요.png](data:image/png;base64,...)

# %% [markdown]
# 이번엔 대회의 룰을 확인해 보도록 하겠습니다. 대회의 룰을 정확히 숙지하고 있어야 대회에 참여할 수 있습니다. 또한 상품이 걸려있는 만큼(본 대회에서는 기간이 종료되었지만) 규칙을 잘 따라야 합니다. 부정행위를 통해 얻은 점수는 무효가 될 뿐만 아니라 향후 캐글의 다른 대회에 참가하는 것에도 불이익이 있을 수 있다는 점, 잊지 마세요.
#
# 본 대회에서는 외부 데이터의 사용을 금하고 있고 하루 최대 제출 횟수도 5번으로 제한된다고 합니다.
#
# ![캐글 대회룰.png](data:image/png;base64,...)

# %% [markdown]
# 그 다음으로는 우리가 사용해야할 데이터에 대해 알아봅시다. 'Data' 탭을 눌러서 데이터에 대한 정보를 확인할 수 있습니다. 각 컬럼 중 3번에 해당하는 `price` 가 우리가 예측해야하는 집값임을 알 수 있죠. 이외에 `Data` 탭의 아래쪽에는 실제로 데이터를 살펴볼 수있는 `Data Explorer`가 존재합니다. 아래 그림처럼 Data ExPlorer를 열어서 데이터의 분포를 살펴볼 수도 있습니다.
#
# 이 대회에서는 `train.csv`라는 모델 학습용 파일과, `test.csv`라는 테스트용 파일, 그리고 `sample_submission.csv`라는 제출용 파일이 제공되고 있음을 확인할 수 있습니다. 앞으로 우리는 `train.csv`를 활용해서 데이터를 뜯어보고 모델을 학습시킨 후, `test.csv` 파일의 데이터에 대해 `price`를 예측해서 `sample_submission.csv`의 형식에 맞
# 게 제출해보겠습니다.
#
# ![캐글 대회데이터2.png](data:image/png;base64,...)
#
# ----

# %% [markdown]
# ### 베이스라인 모델 세팅하기
#
# 이번 대회에서는 주최자가 Baseline을 제공하였습니다. Baseline이라 함은 기본적으로 문제 해결을 시작할 때 쉽게 사용해볼 수 있는 샘플을 이야기합니다.
#
# 따라서 Baseline코드를 살펴보면 데이터에 대한 이해를 높일 수 있을 것 입니다. 아래의 링크를 클릭하여 Baseline 커널로 이동해보죠.
#
# - [2019 ML month 2nd baseline 커널](https://www.kaggle.com/code/kcs93023/2019-ml-month-2nd-baseline/notebook)
#
# 캐글에서 **커널 (Kernel)**은 우리가 많이 사용하는 주피터 노트북 형태로 구글 Colab의 캐글 버젼입니다. 코드를 캐글 서버에서 작성하고, 실행 시켜주고, 다른 사람들과 공유할 수 있는 플랫폼이라고 보시면 됩니다.
#
# Baseline 페이지에 들어가셨다면 아래의 그림과 같이 오른쪽 상단의 `Copy & Edit` 을 클릭해봅시다.
#
# 클릭을 하게 되면 주피터 노트북(Jupyter notebook)과 유사한 환경이 나타납니다. 쥬피터 노트북의 단축키가 거의 동일하게 지원되기 때문에 캐글 커널환경에 금방 익숙해지실 것입니다.
# `shift+enter` 키를 누르면서 baseline모델을 실행해 볼 수 있습니다.
# 우리는 이번 캐글의 데이터를 가지고 와서 여기 Colab에서 바로 실행해보겠습니다.
#
# ![캐글 대회베이스라인.png](data:image/png;base64,...)
#
# ----

# %% [markdown]
# ### 데이터 전처리
#
# 캐글대회에서 제공한 baseline모델을 여기서 실행해 보도록 하겠습니다.
# 첫번째로 실험에 필요한 라이브러리를 임포트(import)해보겠습니다.

# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 이제 데이터를 다운로드해야하는데요, 캐글대회 사이트에서 데이터를 다운로드 받을 수 있지만, 중간에 대회의 데이터가 변경된 히스토리가 있다고 합니다.
# 그래서 아래의 코드를 실행시켜서 Colab환경에서 데이터를 직접 다운로드 해보도록 하겠습니다.

# %%
# 데이터 다운로드
# !wget –no-check-certificate 'https://docs.google.com/uc?export=download&id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0' -O kaggle-kakr-housing-data.zip
# Out:
# 'wget'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'id'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %% [markdown]
# 위 명령어를 실행하고 Colab의 폴더 새로고침을 클릭하면 `kaggle-kakr-housing-data.zip`파일이 다운로드된것을 보실 수 있을겁니다.
#
# ![캐글 데이터불러오기.png](data:image/png;base64,...)

# %% [markdown]
# 이제 아래의 명령어를 이용하여 다운로드 받은 데이터의 압축을 풀겠습니다.
#
# 압축이 풀리면 다시한번 위에 그림과 같이 폴더 새로고침을 클릭해보세요. 그 곳엔 `data`란 폴더가 있고 폴더안에는 다음의 3개의 파일이 있음을 확인하실 수 있습니다.
# - `train.csv` : 학습에 사용할 파일
# - `test.csv` : 테스트에 사용할 파일
# - `sample_submission.csv` : 캐글 대회에 제출할 파일 형식

# %%
# 다운로드 받은 zip파일 압축풀기
# !unzip -qq ./kaggle-kakr-housing-data.zip

# %% [markdown]
# ### 데이터 살펴보기
#
# 이제 데이터를 살펴볼 시간입니다. [원본 데이터를 설명하는 곳](https://rstudio-pubs-static.s3.amazonaws.com/155304_cc51f448116744069664b35e7762999f.html)에서 그 정보를 가져왔습니다. 아래에 정리하였습니다.
#
# 1. ID : 집을 구분하는 번호
# 2. date : 집을 구매한 날짜
# 3. **price : 타겟 변수인 집의 가격**
# 4. bedrooms : 침실의 수
# 5. bathrooms : 침실당 화장실 개수
# 6. sqft_living : 주거 공간의 평방 피트
# 7. sqft_lot : 부지의 평방 피트
# 8. floors : 집의 층수
# 9. waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# 10. view : 집이 얼마나 좋아 보이는지의 정도
# 11. condition : 집의 전반적인 상태
# 12. grade : King County grading 시스템 기준으로 매긴 집의 등급
# 13. sqft_above : 지하실을 제외한 평방 피트
# 14. sqft_basement : 지하실의 평방 피트
# 15. yr_built : 집을 지은 년도
# 16. yr_renovated : 집을 재건축한 년도
# 17. zipcode : 우편번호
# 18. lat : 위도
# 19. long : 경도
# 20. sqft_living15 : 근처 15 가구의 주거 공간, 평방 피트
# 21. sqft_lot15 : 근처 15가구의 부지, 평방 피트
#
#
#
# ---
#
#
#
# 여기서 `3. price`을 제외한 데이터를 이용하여 `3. price` 값을 예측하는 모델을 만들어야 합니다. 먼저 학습데이터와 테스트 데이터를 로드하여 데이터의 형태를 살펴보도록 하겠습니다.

# %%
train_data_path = 'kaggle-kakr-housing-data/train.csv'
test_data_path = 'kaggle-kakr-housing-data/test.csv'

data = pd.read_csv(train_data_path)
sub = pd.read_csv(test_data_path)
print('train data dim : {}'.format(data.shape))
print('sub data dim : {}'.format(sub.shape))
# Out:
# train data dim : (15035, 21)
# sub data dim : (6468, 20)

# %% [markdown]
# 학습 데이터(`data`)는 약 1만 5천개, 테스트 데이터(`sub`)는 약 6천개로 이루어져 있고 테스트 데이터(`sub`)에는 price가 빠져있어서 컬럼이 하나
# 적다는 것을 알 수 있습니다.

# %% [markdown]
# ### 학습 데이터에서 라벨 제거하기
#
# 학습데이터인 `data`는 테스트 데이터인 `sub`와 달리 우리가 예측해야 할 `price`란  컬럼을 하나 더 가지고 있습니다. 이제부터 학습데이터(`data`)의 `price`를 `y`라는 정답을 담는 변수로 옮기고 `data`에서는 `price`컬럼을 제거 하려고 합니다.
#
# 이를 직접 구현해 보세요.
#
# ```
# [힌트]
# - 파이썬의 del 명령어를 사용하여 특정컬럼을 지울 수 있습니다
# - pandas.DataFrame.drop도 활용할 수 있습니다
#
# ```

# %%
# data의 price를 y로 옮기기
y = data['price']
##################
### 미션 코드 2 ####
##################

data = pd.DataFrame(data).drop('price', axis=1)

# %% [markdown]
# 코드를 잘 작성하셨다면 아래의 `data.colums`를 출력하였을 때 Index에 'price'가 없어야 합니다.

# %%
print(data.columns)
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# 모델을 학습시키기 전에 학습데이터와 테스트 데이터를 합쳐서 전체 데이터가 어떤 특성을 보이고 있는지 살펴보려고 합니다. 특성을 살펴보고 난 후엔 다시 분리하여 학습을 진행할것 입니다.
# 이를위해 학습데이터(`data`)의 개수를 저장하여 합쳐진 데이터에서 분리할 것 입니다.
# 아래의 코드는 이를 실행합니다.

# %%
train_len = len(data) # 학습데이터의 수
data = pd.concat((data, sub), axis=0) # 학습데이터와 테스트 데이터 합치기

print(len(data)) # 합쳐진 데이터의 수
data.head() # 데이터 확인
# Out:
# 21503
#    id             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   0  20141013T000000         3       1.00         1180      5650     1.0
# 1   1  20150225T000000         2       1.00          770     10000     1.0
# 2   2  20150218T000000         3       2.00         1680      8080     1.0
# 3   3  20140627T000000         3       2.25         1715      6819     2.0
# 4   4  20150115T000000         3       1.50         1060      9711     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      6         770              0      1933
# 2           0     0          3      8        1680              0      1987
# 3           0     0          3      7        1715              0      1995
# 4           0     0          3      7        1060              0      1963
#
# ...

# %% [markdown]
# `data`를 확인해보면 `data`와 `sub`가 잘 합쳐진 것을 확인하실 수 있을 겁니다.
# 이제부터 데이터에 결측치가 있는지 확인해보겠습니다. 다음으로 가시죠~!!

# %% [markdown]
# **Pandas의 info 함수로 데이터 타입 및 null 체크해보기**
#
# 우리가 배웠던 `info()`함수로 데이터 타입 및 null 체크를 해보겠습니다.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21503 entries, 0 to 6467
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21503 non-null  int64
#  1   date           21503 non-null  object
#  2   bedrooms       21503 non-null  int64
#  3   bathrooms      21503 non-null  float64
#  4   sqft_living    21503 non-null  int64
#  5   sqft_lot       21503 non-null  int64
#  6   floors         21503 non-null  float64
#  7   waterfront     21503 non-null  int64
#  8   view           21503 non-null  int64
#  9   condition      21503 non-null  int64
#  10  grade          21503 non-null  int64
#  11  sqft_above     21503 non-null  int64
#  12  sqft_basement  21503 non-null  int64
#  13  yr_built       21503 non-null  int64
#  14  yr_renovated   21503 non-null  int64
#  15  zipcode        21503 non-null  int64
#  16  lat            21503 non-null  float64
# ...

# %% [markdown]
# ### 결측치 데이터의 비율 계산하기
#
# 위 `info`함수를 이용하면 각 컬럼에 null 데이터가 몇개 존재하는지 확인할 수있습니다. 미션에서는 유사한 방법으로 `isna()`로 결측치 데이터를 확인하고 그 수를 `sum()`함수로 세어보겠습니다.
#
# - 참고 : [`isna()`](https://pandas.pydata.org/docs/reference/api/pandas.isna.html)와 [`sum()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sum.html)

# %%
########################
### 미션 코드작성 3-1 #####
########################
missing = data.isna().sum()
missing
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# 출력하였을 때 다음과 같은 결과가 나오면 됩니다.
#
# > id               0 <br>
# date             0 <br>
# price            0 <br>
# bedrooms         0 <br>
# bathrooms        0 <br>
# sqft_living      0 <br>
# sqft_lot         0 <br>
# floors           0 <br>
# waterfront       0 <br>
# view             0 <br>
# condition        0 <br>
# grade            0 <br>
# sqft_above       0 <br>
# sqft_basement    0 <br>
# yr_built         0 <br>
# yr_renovated     0 <br>
# zipcode          0 <br>
# lat              0 <br>
# long             0 <br>
# sqft_living15    0 <br>
# sqft_lot15       0 <br>
# dtype: int64 <br>

# %% [markdown]
# 이제 missing을 전체 데이터의 수로 나눈다면 컬럼별 결측치 데이터의 비율을 알 수 있게 됩니다.

# %%
missing/data.shape[0]
# Out:
# id               0.0
# date             0.0
# bedrooms         0.0
# bathrooms        0.0
# sqft_living      0.0
# sqft_lot         0.0
# floors           0.0
# waterfront       0.0
# view             0.0
# condition        0.0
# grade            0.0
# sqft_above       0.0
# sqft_basement    0.0
# yr_built         0.0
# yr_renovated     0.0
# zipcode          0.0
# lat              0.0
# long             0.0
# sqft_living15    0.0
# sqft_lot15       0.0
# dtype: float64

# %% [markdown]
# **Pands describe() 함수로 수치형 데이터 기본 통계량 확인**
#
# `describe()`함수를 이용하면 수치형 데이터의 기본적인 통계량을 확인해볼 수 있습니다. 이를 활용해 봅니다.

# %%
data.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  21503.000000  21503.000000  21503.000000  21503.000000  2.150300e+04
# mean   10751.000000      3.371762      2.116042   2081.441334  1.511715e+04
# std     6207.525755      0.930026      0.770018    918.669624  4.147591e+04
# min        0.000000      0.000000      0.000000    290.000000  5.200000e+02
# 25%     5375.500000      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    10751.000000      3.000000      2.250000   1914.000000  7.616000e+03
# 75%    16126.500000      4.000000      2.500000   2550.000000  1.068600e+04
# max    21502.000000     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21503.000000  21503.000000  21503.000000  21503.000000  21503.000000
# mean       1.495140      0.007580      0.234618      3.409710      7.659164
# ...

# %%
import missingno as msno # 라이브러리 임포트
import matplotlib.pyplot as plt 

msno.matrix(data, figsize=(20,6), sparkline=False)
plt.show()

# %%
sub_id = data['id'][train_len:]
del data['id']

print(data.columns)
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data['date'] = data['date'].apply(lambda x : str(x[:6]))
data.head()
# Out:
#      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  201410         3       1.00         1180      5650     1.0           0
# 1  201502         2       1.00          770     10000     1.0           0
# 2  201502         3       2.00         1680      8080     1.0           0
# 3  201406         3       2.25         1715      6819     2.0           0
# 4  201501         3       1.50         1060      9711     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      6         770              0      1933             0
# 2     0          3      8        1680              0      1987             0
# 3     0          3      7        1715              0      1995             0
# 4     0          3      7        1060              0      1963             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
fig, ax = plt.subplots(9, 2, figsize=(12, 50))   # 가로스크롤 때문에 그래프 확인이 불편하다면 figsize의 x값을 조절해 보세요.

# date 변수(count==0인 경우)는 제외하고 분포를 확인
count = 1
columns = data.columns
for row in range(9):
    for col in range(2):
        sns.kdeplot(data=data[columns[count]], ax=ax[row][col])
        ax[row][col].set_title(columns[count], fontsize=15)
        count += 1
        if count == 19 :
            break

# %%
# 치우친 분포의 컬럼을 저장해 두기
skew_columns = ['bedrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'sqft_lot15', 'sqft_living15']

########################
### 미션 코드작성 4 #######
########################

for c in skew_columns:
    data[c] = np.log1p(data[c])

# %%
fig, ax = plt.subplots(4, 2, figsize=(12, 24))

count = 0
for row in range(4):
    for col in range(2):
        if count == 7:
            break
        sns.kdeplot(data=data[skew_columns[count]], ax=ax[row][col])
        ax[row][col].set_title(skew_columns[count], fontsize=15)
        count += 1

# %%
xx = np.linspace(0, 10, 500)
yy = np.log(xx)

plt.hlines(0, 0, 10)
plt.vlines(0, -5, 5)
plt.plot(xx, yy, c='r')
plt.show()

# %%
sns.kdeplot(y) # y는 미션 2에서 price를 저장하고 있음.
plt.show()

# %% [markdown]
# ## ALL RIGHTS RESERVED. (C)NAVER Connect Foundation.

# %%
y_log_transformation = np.log1p(y) # 미션4의 힌트가 되겠네요 ^^

sns.kdeplot(y_log_transformation)
plt.show()

# %%
sub = data.iloc[train_len:, :]
x = data.iloc[:train_len, :]

print(x.shape)
print(sub.shape)
# Out:
# (15035, 19)
# (6468, 19)
